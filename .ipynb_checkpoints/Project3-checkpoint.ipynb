# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import json

# %%
from Getting_data import Data_cleaning
from visualizations import visualizations

# %%
#The list of all symbols
symbols = ['SLV', 'SIL', 'GLD','GDX', 'DJI']

#Defining an object
metal_object = Data_cleaning(function='TIME_SERIES_DAILY',
                  symbol = symbols,
                  outputsize='full',
                  datatype = 'json', 
                  path = '/Users/jalalkiani/.secret/Alpha_Vantage.json')

# %%
df_metal = metal_object.getting_cleaning_data(False)
# Out:
# The number of null values in SLV is 0
# The number of null values in SIL is 0
# The number of null values in GLD is 0
# The number of null values in GDX is 0
# The number of null values in DJI is 0

# %%
df_metal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17849 entries, 0 to 4970
# Data columns (total 10 columns):
# Time      17849 non-null datetime64[ns]
# Open      17849 non-null float64
# High      17849 non-null float64
# Low       17849 non-null float64
# Close     17849 non-null float64
# volume    17849 non-null int64
# symbol    17849 non-null object
# Year      17849 non-null int64
# Month     17849 non-null int64
# Day       17849 non-null int64
# dtypes: datetime64[ns](1), float64(4), int64(4), object(1)
# memory usage: 1.5+ MB

# %% [markdown]
# #  Visualizations

# %%
symbols = ['SLV', 'SIL', 'GLD','GDX']
visualizations(df_metal.copy(), symbols,
               type_price = 'Close',
               start_date = '2010-01-01', 
               end_date = '2019-10-04', 
               fill_na = 'ffill',
               moving_average_plot = False,
               short_window = 20,
               long_window = 100)
